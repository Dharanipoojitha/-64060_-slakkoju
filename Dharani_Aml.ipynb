# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharanipoojitha/-64060_-slakkoju/blob/main/Dharani_Aml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)

# %%
print(train_data,train_data.shape)
# Out:
# [list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32])
#  list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 2, 4, 1153, 9, 194, 775, 7, 8255, 2, 349, 2637, 148, 605, 2, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95])
#  list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113])
#  ...
#  list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 2, 325, 725, 134, 2, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 2, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 2, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 2, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 2, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 2, 5, 27, 710, 117, 2, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 2, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 2, 7750, 5, 4241, 18, 4, 8497, 2, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 2, 4, 3586, 2])
#  list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23])
#  list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 2, 21, 27, 9685, 6139, 5, 2, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 2, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 2, 2, 544, 5, 383, 1271, 848, 1468, 2, 497, 2, 8, 1597, 8778, 2, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])] (25000,)

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
len(train_labels)
# Out:
# 25000

# %%
test_labels[0]
# Out:
# 0

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
#Decoding reviews go to the next
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %% [markdown]
# #Only the top 10,000 most common terms in the training set will be retained accordingly
# #The list of reviews that make up the variable strain data and test data are listed
# #As a result of our restriction to the top 10,000 most frequently occurring words

# %% [markdown]
# #Preparation of the data
#
# #List of integers cannot be found into neural network. Our lists must be transformed.
#
# #One possible solution is to create an integer tensor of the form samples to convert our list into vector of zeros and ones we could one hot and cut them. We will choose the second option now let’s activate our data which will be done.

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i,sequence] = 1
    return results
# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
x_test[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
layers.Dense(16, activation="relu"),
layers.Dense(16, activation="relu"),
layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
tf.random.set_seed(1234)
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.5690 - loss: 0.6578 - val_accuracy: 0.8501 - val_loss: 0.5309
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8490 - loss: 0.4830 - val_accuracy: 0.8764 - val_loss: 0.3909
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9002 - loss: 0.3381 - val_accuracy: 0.8870 - val_loss: 0.3185
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9205 - loss: 0.2545 - val_accuracy: 0.8899 - val_loss: 0.2904
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9335 - loss: 0.2059 - val_accuracy: 0.8886 - val_loss: 0.2833
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9454 - loss: 0.1707 - val_accuracy: 0.8877 - val_loss: 0.2808
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9562 - loss: 0.1450 - val_accuracy: 0.8842 - val_loss: 0.2843
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9641 - loss: 0.1215 - val_accuracy: 0.8828 - val_loss: 0.2987
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9694 - loss: 0.1055 - val_accuracy: 0.8825 - val_loss: 0.3082
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9736 - loss: 0.0916 - val_accuracy: 0.8821 - val_loss: 0.3220
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9797 - loss: 0.0774 - val_accuracy: 0.8816 - val_loss: 0.3391
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9857 - loss: 0.0640 - val_accuracy: 0.8795 - val_loss: 0.3566
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9880 - loss: 0.0555 - val_accuracy: 0.8780 - val_loss: 0.3746
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9914 - loss: 0.0477 - val_accuracy: 0.8782 - val_loss: 0.3947
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9905 - loss: 0.0433 - val_accuracy: 0.8755 - val_loss: 0.4099
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9948 - loss: 0.0338 - val_accuracy: 0.8765 - val_loss: 0.4367
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9972 - loss: 0.0249 - val_accuracy: 0.8756 - val_loss: 0.4554
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9981 - loss: 0.0202 - val_accuracy: 0.8758 - val_loss: 0.4783
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9982 - loss: 0.0199 - val_accuracy: 0.8754 - val_loss: 0.4995
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9984 - loss: 0.0174 - val_accuracy: 0.8742 - val_loss: 0.5239

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
loss=history_dict["loss"]
val_loss=history_dict["val_loss"]
epochs = range(1, len(acc) + 1)
#bo
plt.plot(epochs, loss, "bo", label="Training loss")
#b
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc_values = history_dict["accuracy"]
val_acc_values = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model=keras.Sequential([
layers.Dense(16,activation="relu"),
layers.Dense(16,activation="relu"),
layers.Dense(1,activation="sigmoid")
])
model.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
model.fit(x_train,y_train,epochs=4,batch_size=512)
results=model.evaluate(x_test,y_test)
# Out:
# Epoch 1/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.7147 - loss: 0.5795
# Epoch 2/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8930 - loss: 0.3099
# Epoch 3/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9152 - loss: 0.2320
# Epoch 4/4
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9295 - loss: 0.1937
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8838 - loss: 0.2863

# %%
results
# Out:
# [0.2862599492073059, 0.8849999904632568]

# %%
model.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.18165034],
#        [0.9991019 ],
#        [0.81508356],
#        ...,
#        [0.0920101 ],
#        [0.06251436],
#        [0.50087315]], dtype=float32)

# %%
model_1_layer = keras.Sequential([
layers.Dense(16, activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_1_layer.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
x_val1 = x_train[:10000]
partial_x_train = x_train[10000:]
y_val1 = y_train[:10000]
partial_y_train = y_train[10000:]
history1_layer= model_1_layers.fit(partial_x_train,
                                     partial_y_train,
                                    epochs=20,
                                    batch_size=512,
validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9890 - loss: 0.0574 - val_accuracy: 0.8782 - val_loss: 0.3777
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9907 - loss: 0.0527 - val_accuracy: 0.8763 - val_loss: 0.3881
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9914 - loss: 0.0486 - val_accuracy: 0.8755 - val_loss: 0.3990
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9923 - loss: 0.0448 - val_accuracy: 0.8737 - val_loss: 0.4099
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9934 - loss: 0.0415 - val_accuracy: 0.8736 - val_loss: 0.4209
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9949 - loss: 0.0385 - val_accuracy: 0.8723 - val_loss: 0.4316
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9949 - loss: 0.0367 - val_accuracy: 0.8717 - val_loss: 0.4413
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9967 - loss: 0.0330 - val_accuracy: 0.8715 - val_loss: 0.4525
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9971 - loss: 0.0302 - val_accuracy: 0.8714 - val_loss: 0.4648
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9970 - loss: 0.0290 - val_accuracy: 0.8705 - val_loss: 0.4742
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9982 - loss: 0.0259 - val_accuracy: 0.8700 - val_loss: 0.4855
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9986 - loss: 0.0244 - val_accuracy: 0.8697 - val_loss: 0.4973
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9988 - loss: 0.0225 - val_accuracy: 0.8694 - val_loss: 0.5088
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9990 - loss: 0.0220 - val_accuracy: 0.8691 - val_loss: 0.5193
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9995 - loss: 0.0196 - val_accuracy: 0.8683 - val_loss: 0.5310
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9997 - loss: 0.0183 - val_accuracy: 0.8684 - val_loss: 0.5431
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9997 - loss: 0.0170 - val_accuracy: 0.8680 - val_loss: 0.5541
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9997 - loss: 0.0160 - val_accuracy: 0.8670 - val_loss: 0.5652
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9997 - loss: 0.0150 - val_accuracy: 0.8673 - val_loss: 0.5759
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9998 - loss: 0.0135 - val_accuracy: 0.8668 - val_loss: 0.5902

# %%
history_dict1 = history1_layer.history
history_dict1.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt
history_dict1 = history1_layer.history
loss_value1 = history_dict1["loss"]
val_loss_value1 = history_dict1["val_loss"]
epochs1 = range(1, len(loss_value1) + 1)
plt.plot(epochs1, loss_value1, "bo", label="Training loss")
plt.plot(epochs1, val_loss_value1, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
plt.clf()
accuracy1 = history_dict1["accuracy"]
val_accuracy1 = history_dict1["val_accuracy"]
plt.plot(epochs1, accuracy1, "bo", label="Training acc")
plt.plot(epochs1, val_accuracy1, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model_1_layer = keras.Sequential([
layers.Dense(16, activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_1_layer.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
model_1_layer.fit(x_train,y_train,epochs=5,batch_size=512)
result_1_layer=model_1_layer.evaluate(x_test,y_test)
# Out:
# Epoch 1/5
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7347 - loss: 0.5509
# Epoch 2/5
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8976 - loss: 0.3076
# Epoch 3/5
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9163 - loss: 0.2413
# Epoch 4/5
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9270 - loss: 0.2073
# Epoch 5/5
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9362 - loss: 0.1850
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8847 - loss: 0.2821

# %%
print(result_1_layer)
# Out:
# [0.28097155690193176, 0.8861600160598755]

# %%
model_1_layer.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.22845207],
#        [0.9994904 ],
#        [0.7229969 ],
#        ...,
#        [0.12858683],
#        [0.07947275],
#        [0.5429399 ]], dtype=float32)

# %%
model_3_layer  = keras.Sequential([
layers.Dense(16, activation="relu"),
layers.Dense(16, activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_3_layer.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
x_val3 = x_train[:10000]
partial_x_train = x_train[10000:]
y_val3 = y_train[:10000]
partial_y_train = y_train[10000:]
history3_layer= model_3_layer.fit(partial_x_train,
                                     partial_y_train,
                                    epochs=20,
                                    batch_size=512,
validation_data = (x_val, y_val3))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.7080 - loss: 0.6012 - val_accuracy: 0.8545 - val_loss: 0.4111
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8856 - loss: 0.3536 - val_accuracy: 0.8870 - val_loss: 0.3168
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9134 - loss: 0.2577 - val_accuracy: 0.8855 - val_loss: 0.2891
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9262 - loss: 0.2108 - val_accuracy: 0.8899 - val_loss: 0.2755
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9423 - loss: 0.1748 - val_accuracy: 0.8875 - val_loss: 0.2767
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9507 - loss: 0.1473 - val_accuracy: 0.8848 - val_loss: 0.2851
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9602 - loss: 0.1250 - val_accuracy: 0.8834 - val_loss: 0.2944
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9647 - loss: 0.1101 - val_accuracy: 0.8826 - val_loss: 0.3077
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9698 - loss: 0.0971 - val_accuracy: 0.8808 - val_loss: 0.3214
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9739 - loss: 0.0844 - val_accuracy: 0.8805 - val_loss: 0.3382
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9788 - loss: 0.0732 - val_accuracy: 0.8779 - val_loss: 0.3548
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9832 - loss: 0.0632 - val_accuracy: 0.8768 - val_loss: 0.3732
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9867 - loss: 0.0540 - val_accuracy: 0.8760 - val_loss: 0.3941
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9879 - loss: 0.0479 - val_accuracy: 0.8735 - val_loss: 0.4138
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9922 - loss: 0.0392 - val_accuracy: 0.8712 - val_loss: 0.4367
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9940 - loss: 0.0344 - val_accuracy: 0.8714 - val_loss: 0.4606
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9929 - loss: 0.0322 - val_accuracy: 0.8708 - val_loss: 0.4804
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9963 - loss: 0.0248 - val_accuracy: 0.8690 - val_loss: 0.5045
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9959 - loss: 0.0230 - val_accuracy: 0.8681 - val_loss: 0.5263
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9987 - loss: 0.0180 - val_accuracy: 0.8679 - val_loss: 0.5490

# %%
history_dict3 = history3_layer.history
history_dict3.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
loss_value3 = history_dict3["loss"]
val_loss_value3 = history_dict3["val_loss"]
epochs3 = range(1, len(loss_value3) + 1)
plt.plot(epochs3, loss_value3, "bo", label="Training loss")
plt.plot(epochs3, val_loss_value3, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
plt.clf()
accuracy3 = history_dict3["accuracy"]
val_accuracy3 = history_dict3["val_accuracy"]
plt.plot(epochs3, accuracy3, "bo", label="Training acc")
plt.plot(epochs3, val_accuracy3, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model_3_layer = keras.Sequential([
layers.Dense(16, activation="relu"),
layers.Dense(16, activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_3_layer.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
model_3_layer.fit(x_train,y_train,epochs=3,batch_size=512)
result_3_layer=model_3_layer.evaluate(x_test,y_test)
# Out:
# Epoch 1/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7304 - loss: 0.5512
# Epoch 2/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8984 - loss: 0.2802
# Epoch 3/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9217 - loss: 0.2114
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8845 - loss: 0.2822

# %%
print(result_3_layer)
# Out:
# [0.28027093410491943, 0.8871999979019165]

# %%
model_3_layer.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.22730677],
#        [0.9975175 ],
#        [0.92716753],
#        ...,
#        [0.14700933],
#        [0.07907198],
#        [0.5445144 ]], dtype=float32)

# %%
model_32_units = keras.Sequential([
layers.Dense(32, activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_32_units.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
x_val32 = x_train[:10000]
partial_x_train = x_train[10000:]
y_val32 = y_train[:10000]
partial_y_train = y_train[10000:]
history32_units= model_32_units.fit(partial_x_train,
                                    partial_y_train,
                                    epochs=20,
                                    batch_size=512,
validation_data = (x_val, y_val32))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.6939 - loss: 0.5762 - val_accuracy: 0.8575 - val_loss: 0.3904
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8855 - loss: 0.3350 - val_accuracy: 0.8835 - val_loss: 0.3124
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9122 - loss: 0.2585 - val_accuracy: 0.8885 - val_loss: 0.2876
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9263 - loss: 0.2168 - val_accuracy: 0.8875 - val_loss: 0.2781
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9354 - loss: 0.1878 - val_accuracy: 0.8855 - val_loss: 0.2769
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9445 - loss: 0.1671 - val_accuracy: 0.8862 - val_loss: 0.2786
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9512 - loss: 0.1494 - val_accuracy: 0.8847 - val_loss: 0.2818
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9568 - loss: 0.1354 - val_accuracy: 0.8831 - val_loss: 0.2885
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9622 - loss: 0.1227 - val_accuracy: 0.8827 - val_loss: 0.2935
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9668 - loss: 0.1126 - val_accuracy: 0.8822 - val_loss: 0.3020
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9714 - loss: 0.1036 - val_accuracy: 0.8815 - val_loss: 0.3098
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9725 - loss: 0.0952 - val_accuracy: 0.8813 - val_loss: 0.3179
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9763 - loss: 0.0863 - val_accuracy: 0.8803 - val_loss: 0.3287
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9790 - loss: 0.0804 - val_accuracy: 0.8809 - val_loss: 0.3369
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9828 - loss: 0.0736 - val_accuracy: 0.8791 - val_loss: 0.3466
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9846 - loss: 0.0662 - val_accuracy: 0.8790 - val_loss: 0.3571
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9883 - loss: 0.0598 - val_accuracy: 0.8778 - val_loss: 0.3683
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9884 - loss: 0.0564 - val_accuracy: 0.8776 - val_loss: 0.3779
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9915 - loss: 0.0499 - val_accuracy: 0.8760 - val_loss: 0.3902
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9907 - loss: 0.0477 - val_accuracy: 0.8752 - val_loss: 0.4012

# %%
history_dict32 = history32_units.history
history_dict32.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
loss_value32 = history_dict32["loss"]
val_loss_value32 = history_dict32["val_loss"]
epochs32 = range(1, len(loss_value32) + 1)
plt.plot(epochs32, loss_value32, "bo", label="Training loss")
plt.plot(epochs32, val_loss_value32, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
plt.clf()
accuracy32 = history_dict32["accuracy"]
val_accuracy32 = history_dict32["val_accuracy"]
plt.plot(epochs32, accuracy32, "bo", label="Training acc")
plt.plot(epochs32, val_accuracy32, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_32_units = model_32_units.fit(x_train,y_train,epochs=3,batch_size=512)
results_32_units=model_32_units.evaluate(x_test,y_test)
results_32_units
# Out:
# Epoch 1/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9437 - loss: 0.1903
# Epoch 2/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9567 - loss: 0.1391
# Epoch 3/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9614 - loss: 0.1215
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8634 - loss: 0.3829
# [0.3753112256526947, 0.8677200078964233]

# %%
model_32_units.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# array([[0.05257824],
#        [0.99999756],
#        [0.29468524],
#        ...,
#        [0.05592369],
#        [0.04418489],
#        [0.94273394]], dtype=float32)

# %%
model_64_units = keras.Sequential([
layers.Dense(64, activation="relu"),
layers.Dense(64,activation="relu"),
layers.Dense(1, activation="sigmoid")
])
model_64_units.compile(optimizer="rmsprop",
loss="binary_crossentropy",
metrics=["accuracy"])
x_val_64 = x_train[:10000]
partial_x_train = x_train[10000:]
y_val_64 = y_train[:10000]
partial_y_train = y_train[10000:]
history_64_units= model_64_units.fit(partial_x_train,
                                    partial_y_train,
                                    epochs=20,
                                    batch_size=512,
validation_data = (x_val, y_val_64))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - accuracy: 0.6484 - loss: 0.5907 - val_accuracy: 0.8109 - val_loss: 0.4199
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8719 - loss: 0.3173 - val_accuracy: 0.8598 - val_loss: 0.3391
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9068 - loss: 0.2421 - val_accuracy: 0.8882 - val_loss: 0.2762
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9303 - loss: 0.1820 - val_accuracy: 0.8837 - val_loss: 0.2864
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9466 - loss: 0.1493 - val_accuracy: 0.8841 - val_loss: 0.2969
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9524 - loss: 0.1285 - val_accuracy: 0.8805 - val_loss: 0.3129
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.9557 - loss: 0.1196 - val_accuracy: 0.8835 - val_loss: 0.3277
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9734 - loss: 0.0809 - val_accuracy: 0.8806 - val_loss: 0.3492
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9755 - loss: 0.0708 - val_accuracy: 0.8785 - val_loss: 0.3811
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9799 - loss: 0.0601 - val_accuracy: 0.8772 - val_loss: 0.4135
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9902 - loss: 0.0379 - val_accuracy: 0.8768 - val_loss: 0.4128
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.9967 - loss: 0.0215 - val_accuracy: 0.8753 - val_loss: 0.4325
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9993 - loss: 0.0125 - val_accuracy: 0.8738 - val_loss: 0.4779
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9898 - loss: 0.0345 - val_accuracy: 0.8728 - val_loss: 0.4823
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9998 - loss: 0.0072 - val_accuracy: 0.8726 - val_loss: 0.5256
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9926 - loss: 0.0299 - val_accuracy: 0.8754 - val_loss: 0.5181
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8747 - val_loss: 0.5558
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9936 - loss: 0.0231 - val_accuracy: 0.8757 - val_loss: 0.5404
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8750 - val_loss: 0.5758
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9966 - loss: 0.0122 - val_accuracy: 0.8760 - val_loss: 0.5705

# %%
history_dict_64 = history_64_units.history
history_dict_64.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
loss_value_64 = history_dict_64["loss"]
val_loss_value_64 = history_dict_64["val_loss"]
epochs_64 = range(1, len(loss_value_64) + 1)
plt.plot(epochs_64, loss_value_64, "bo", label="Training loss")
plt.plot(epochs_64, val_loss_value_64, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
plt.clf()
accracy_64 = history_dict_64["accuracy"]
val_accuracy_64 = history_dict_64["val_accuracy"]
plt.plot(epochs_64, accracy_64, "bo", label="Training acc")
plt.plot(epochs_64, val_accuracy_64, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_64_units = model_64_units.fit(x_train,y_train,epochs=3,batch_size=512)
results_64_units=model_64_units.evaluate(x_test,y_test)
results_64_units
# Out:
# Epoch 1/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9881 - loss: 0.0325
# Epoch 2/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9980 - loss: 0.0099
# Epoch 3/3
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9987 - loss: 0.0070
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8675 - loss: 0.5076
# [0.5077674388885498, 0.86735999584198]

# %%
model_64_units.predict(x_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# array([[2.9041967e-03],
#        [1.0000000e+00],
#        [4.9471235e-01],
#        ...,
#        [7.9619801e-03],
#        [6.3632673e-04],
#        [9.9806184e-01]], dtype=float32)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

model_128units = keras.Sequential([
    layers.Dense(128, activation="relu"),
    layers.Dense(128, activation="relu"),
    layers.Dense(128, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model_128units.compile(optimizer="rmsprop",
                      loss="binary_crossentropy",
                      metrics=["accuracy"])
x_val_128 = x_train[:10000]
partial_x_train = x_train[10000:]
y_val_128 = y_train[:10000]
partial_y_train = y_train[10000:] # Corrected the slicing to y_train[10000:]
history_128 = model_128units.fit(partial_x_train,
                                 partial_y_train,
                                 epochs=20,
                                 batch_size=512,
                                 validation_data = (x_val_128, y_val_128))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 176ms/step - accuracy: 0.6817 - loss: 0.6203 - val_accuracy: 0.8480 - val_loss: 0.3687
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8752 - loss: 0.3160 - val_accuracy: 0.8764 - val_loss: 0.3035
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9001 - loss: 0.2455 - val_accuracy: 0.8724 - val_loss: 0.3127
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9182 - loss: 0.1981 - val_accuracy: 0.8866 - val_loss: 0.2837
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.9435 - loss: 0.1487 - val_accuracy: 0.8826 - val_loss: 0.2946
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.9632 - loss: 0.1028 - val_accuracy: 0.8829 - val_loss: 0.3497
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9647 - loss: 0.0933 - val_accuracy: 0.8816 - val_loss: 0.3162
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9941 - loss: 0.0299 - val_accuracy: 0.8816 - val_loss: 0.4405
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9730 - loss: 0.0929 - val_accuracy: 0.8810 - val_loss: 0.4421
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9989 - loss: 0.0069 - val_accuracy: 0.8770 - val_loss: 0.5621
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.9706 - loss: 0.1555 - val_accuracy: 0.8795 - val_loss: 0.5007
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9998 - loss: 0.0024 - val_accuracy: 0.8804 - val_loss: 0.6030
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 1.0000 - loss: 8.7612e-04 - val_accuracy: 0.8803 - val_loss: 0.6971
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.9968 - loss: 0.0201 - val_accuracy: 0.8760 - val_loss: 0.6871
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8811 - val_loss: 0.6250
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 1.0000 - loss: 5.7508e-04 - val_accuracy: 0.8817 - val_loss: 0.6743
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 1.0000 - loss: 3.2234e-04 - val_accuracy: 0.8811 - val_loss: 0.7451
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 1.0000 - loss: 1.7923e-04 - val_accuracy: 0.8805 - val_loss: 0.8008
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 1.0000 - loss: 1.1249e-04 - val_accuracy: 0.8805 - val_loss: 0.8375
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 1.0000 - loss: 7.8993e-05 - val_accuracy: 0.8802 - val_loss: 0.8627
